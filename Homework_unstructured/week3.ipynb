# %%
n=10
x=0
for i in range(1, n+1):
    k=i+1
    while k<=n:
        x=x+1
        k+=1
print(x)
# Out:
# 45

# %%
def f(n):
    return n**2+3*n+4
def g(n):
    return 6*n+7

# %%
def f_2(n):
    return n*(n**(1/2))
def g_2(n):
    return n**2-n

# %%
def f_3(n):
    return 2**n-n**2
def g_3(n):
    return n**4+n**2

# %%
if f_3(2^1000)>=100000000000000000000000000000*g_3(2^1000):
    print(">=")
else: print("<")
# Out:
# >=

# %%
# for f(n), g(n)
import matplotlib.pyplot as plt
f = [n**2+3*n+4 for n in range(50)]
g = [6*n+7 for n in range(50)]
plt.plot(f, "o-b", g, "o--r")
plt.show()

# %%
f_2 = [n*(n**(1/2)) for n in range(50)]
g_2 = [n**2-n for n in range(50)]
plt.plot(f_2, "o-b", g_2, "o--r")
plt.show()

# %%
f_3 = [2**n-n**2 for n in range(50)]
g_3 = [n**4+n**2 for n in range(50)]
plt.plot(f_3, "o-b", g_3, "o--r")
plt.show()
